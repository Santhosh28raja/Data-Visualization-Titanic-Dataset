# %% [markdown]
# <font size=4 color='red'>  **Dataset:** </font> <font size=3>Titanic data
#
# <font size=4 color='red'>  **Dataset source:**</font> https://www.kaggle.com/datasets/brendan45774/test-file
#
# <font size=4 color='red'>  **Attribute Information**</font>
# - Survived: Outcome of survival (0 = No; 1 = Yes)
# - Pclass: Socio-economic class (1 = Upper class; 2 = Middle class; 3 = Lower class)
# - Name: Name of passenger
# - Sex: Sex of the passenger
# - Age: Age of the passenger (Some entries contain NaN)
# - SibSp: Number of siblings and spouses of the passenger aboard
# - Parch: Number of parents and children of the passenger aboard
# - Ticket: Ticket number of the passenger
# - Fare: Fare paid by the passenger
# - Cabin: Cabin number of the passenger (Some entries contain NaN)
# - Embarked: Port of embarkation of the passenger (C = Cherbourg; Q = Queenstown; S = Southampton)

# %% [markdown]
# <font size=4>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('Titanic+Data+Set.csv')

# %% [markdown]
# <font size=4>

# %% [markdown]
# ### Basic Exploratory Data Analysis (EDA)

# %% [markdown]
# <font size=4>

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.shape
# Out:
# (891, 12)

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.drop('PassengerId',axis=1,inplace=True)

# %% [markdown]
# <font size=4>

# %% [markdown]
# <font size=4> Q1. From which port the maximum number of people boarded the titanic? Use an appropriate plot.

# %% [markdown]
# <font size=4>

# %% [markdown]
# ### Count plot

# %%
sns.countplot(x='Embarked',data=data)
plt.title('Number of People Boarded from Each Port')
plt.xlabel('Embarked')
plt.ylabel('Passengers')
plt.show()

# %% [markdown]
# ### Bar plot

# %%
port_counts = data['Embarked'].value_counts()
port_counts
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
plt.bar(port_counts.index, port_counts.values,color=['red','blue','green'])
plt.title('Number of People Boarded from Each Port')
plt.xlabel('Port')
plt.ylabel('Number of People')
plt.show()

# %% [markdown]
# <font size=4>

# %% [markdown]
# <font size=4> Q2. Visualize the relationship between ticket fare paid and age of the passengers using scatter plot and write your inferences.

# %% [markdown]
# <font size=4>

# %% [markdown]
# ### Sns Scatter plot

# %%
sns.scatterplot(x=data['Age'], y=data['Fare'])
plt.title('Relationship between Ticket Fare and Age of Passengers')
plt.xlabel('Age')
plt.ylabel('Fare')

plt.show()

# %% [markdown]
# ### Plt Scatter plot

# %%
plt.scatter(data['Age'], data['Fare'])

plt.title('Relationship between Ticket Fare and Age of Passengers')
plt.xlabel('Age')
plt.ylabel('Ticket Fare')

plt.show()

# %% [markdown]
# <font size=4>

# %% [markdown]
# <font size=4>  Q3. Check the distribution of age of the passengers using Histplot.

# %% [markdown]
# <font size=4>

# %% [markdown]
# ### Sns Hist plot

# %%
sns.histplot(data,x='Age',bins=20,kde=True)    #kde --> Kernel Density estimator, gives a probability density function of the data on the histogram 

plt.title('Distribution of Age of the Passengers')
plt.xlabel('Age')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# ### Plt Hist plot

# %%
plt.hist(data['Age'])

plt.title('Distribution of Age of the Passengers')
plt.xlabel('Age')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# <font size=4>

# %% [markdown]
# <font size=4> Q4. Check the percentage of the male and female passengers boarded the titanic.

# %% [markdown]
# <font size=4>

# %% [markdown]
# ### Plt Pie plot

# %%
x=data['Sex'].value_counts()
plt.pie(x,labels=['Male','Female'],autopct='%.2f%%',startangle=90)
plt.show()

# %% [markdown]
# <font size=4>

# %% [markdown]
# <font size=4> Q5. Check the statistical summary of the column 'Fare' using Boxplot and write your findings.

# %% [markdown]
# ### Sns Box plot

# %%
sns.boxplot(y=data['Fare'])

plt.title('Statistical Summary of the Fare')
plt.ylabel('Fare')

plt.show()

# %% [markdown]
# ### Plt Box plot

# %%
plt.boxplot(data['Fare'],labels=['Fare'])

plt.show()

# %% [markdown]
# <font size=4>

# %% [markdown]
# <font size=4> Q6. Visualize the column age of passengers using displot.

# %% [markdown]
# <font size=4>

# %% [markdown]
# ### Sns Dist plot

# %%
sns.distplot(data['Age'],kde=True)

plt.show()

# %% [markdown]
# <font size=4>

# %% [markdown]
# <font size=4> Q7. Count the number of passengers in different classes using appropriate plot.

# %% [markdown]
# <font size=4>

# %% [markdown]
# ### Count plot

# %%
sns.countplot(x=data['Pclass'])

plt.title('Number of Passengers in the Different Classes')
plt.xlabel('Class')
plt.ylabel('Number of Passengers')

plt.show()

# %% [markdown]
# <font size=4>

# %% [markdown]
# <font size=4> Q8. Visualize the survival rate both is males and females using catplot.

# %% [markdown]
# <font size=4>

# %%
sns.catplot(x='Sex', y='Age', data=data, kind='strip', hue='Survived')
plt.show()

# %%
sns.catplot(x='Sex', y='Age', data=data, kind='swarm', hue='Survived')
plt.show()

# %% [markdown]
# <font size=4>

# %% [markdown]
# <font size=4> Q9. Check the distribution of the males and females among different ticket classes.

# %% [markdown]
# <font size=4>

# %% [markdown]
# ### Cat plot

# %%
sns.catplot(x='Pclass', data=data, kind='count', hue='Sex')

plt.title('Distribution of Male and Female among the Different ticket classes')
plt.xlabel('Class')
plt.ylabel('Count')

plt.show()

# %% [markdown]
# ### Rel plot

# %%
sns.relplot(x='Age',y='Fare',data=data, kind='line', hue='Sex',style='Sex',col='Pclass')

plt.show()

# %% [markdown]
# <font size=4>

# %% [markdown]
# <font size=4> Q10. Visualize and analyse the relationship between Ticket classes, Survivial rate, and Gender of the passengers using appropriate plot

# %% [markdown]
# <font size=4>

# %% [markdown]
# ### Cat plot

# %%
data['Survived'] = data['Survived'].astype(str)

sns.catplot(x='Pclass', hue='Survived', col='Sex', kind='count', data=data)

plt.suptitle('Survival Count by Gender and Class', y=1.02)
plt.show()

# %% [markdown]
# ### Rel plot

# %%
sns.relplot(x='Age',y='Fare',data=data, kind='scatter', hue='Sex',style='Sex',col='Pclass',row='Survived')

plt.show()

# %% [markdown]
# <font size=4>

# %% [markdown]
# <font size=4> Q11. Check the death rate with respect to age of the passengers and three different ticket classes

# %% [markdown]
# <font size=4>

# %% [markdown]
# ### Box plot

# %%
sns.boxplot(x='Pclass',y='Age',hue='Survived',data=data)

plt.title('Death Rate with Respect to Age in Different Ticket Classes')
plt.xlabel('Class')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# ### FacetGrid object

# %%
g=sns.FacetGrid(data,col='Survived',row='Pclass')
g.map(plt.hist,'Age')
g.add_legend()
plt.show()

# %% [markdown]
# <font size=4>

# %% [markdown]
# <font size=4> Q12. Visualize the multiple pairwise bivariate distribution using appropriate plot.

# %% [markdown]
# <font size=4>

# %% [markdown]
# ### Pair plot

# %%
sns.pairplot(data, hue = 'Survived', kind = "scatter", palette = "husl")
plt.show()

# %% [markdown]
# # Thank you
